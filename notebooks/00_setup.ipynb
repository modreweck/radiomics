# %% [markdown]
# Project imports and path resolution

# %%
# Standard library
import sys
from pathlib import Path

# Ensure project root is in PYTHONPATH
PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root resolved to: {PROJECT_ROOT}")
# Out:
# Project root resolved to: c:\Users\modre\Documents\masseter

# %% [markdown]
# Import project configuration

# %%
from src.config import get_paths, set_seed

# %% [markdown]
# Initialize paths and folders

# %%
paths = get_paths()

paths
# Out:
# ProjectPaths(root=WindowsPath('c:/Users/modre/Documents/masseter'), data=WindowsPath('c:/Users/modre/Documents/masseter/data'), raw=WindowsPath('c:/Users/modre/Documents/masseter/data/raw'), processed=WindowsPath('c:/Users/modre/Documents/masseter/data/processed'), results=WindowsPath('c:/Users/modre/Documents/masseter/results'), figures=WindowsPath('c:/Users/modre/Documents/masseter/results/figures'), tables=WindowsPath('c:/Users/modre/Documents/masseter/results/tables'), text=WindowsPath('c:/Users/modre/Documents/masseter/results/text'), supplementary=WindowsPath('c:/Users/modre/Documents/masseter/supplementary'), supp_shap=WindowsPath('c:/Users/modre/Documents/masseter/supplementary/shap'), supp_tables=WindowsPath('c:/Users/modre/Documents/masseter/supplementary/tables'), supp_text=WindowsPath('c:/Users/modre/Documents/masseter/supplementary/text'))

# %% [markdown]
# Set global random seed

# %%
SEED = set_seed(42)
SEED
# Out:
# 42

# %% [markdown]
# Environment validation (versions)

# %%
import numpy as np
import pandas as pd
import sklearn
import lightgbm
import shap

print("Environment versions:")
print(f"Python     : {sys.version.split()[0]}")
print(f"NumPy      : {np.__version__}")
print(f"Pandas     : {pd.__version__}")
print(f"scikit-learn: {sklearn.__version__}")
print(f"LightGBM   : {lightgbm.__version__}")
print(f"SHAP       : {shap.__version__}")
# Out:
# Environment versions:
# Python     : 3.13.11
# NumPy      : 2.3.5
# Pandas     : 2.3.3
# scikit-learn: 1.8.0
# LightGBM   : 4.6.0
# SHAP       : 0.50.0

# %% [markdown]
# Final sanity check

# %%
print("Setup completed successfully.")
print("Project folders:")
for attr, value in paths.__dict__.items():
    print(f"{attr:15s}: {value}")
# Out:
# Setup completed successfully.
# Project folders:
# root           : c:\Users\modre\Documents\masseter
# data           : c:\Users\modre\Documents\masseter\data
# raw            : c:\Users\modre\Documents\masseter\data\raw
# processed      : c:\Users\modre\Documents\masseter\data\processed
# results        : c:\Users\modre\Documents\masseter\results
# figures        : c:\Users\modre\Documents\masseter\results\figures
# tables         : c:\Users\modre\Documents\masseter\results\tables
# text           : c:\Users\modre\Documents\masseter\results\text
# supplementary  : c:\Users\modre\Documents\masseter\supplementary
# supp_shap      : c:\Users\modre\Documents\masseter\supplementary\shap
# supp_tables    : c:\Users\modre\Documents\masseter\supplementary\tables
# supp_text      : c:\Users\modre\Documents\masseter\supplementary\text
